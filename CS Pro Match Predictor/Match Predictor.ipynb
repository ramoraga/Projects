# %% [markdown]
# Reading Match Data

# %%
import pandas as pd
matches = pd.read_csv('results.csv')
matches.head()
# Out:
#          date               team_1          team_2     _map  result_1  \
# 0  2020-03-18              Recon 5         TeamOne    Dust2         0
# 1  2020-03-18              Recon 5         TeamOne  Inferno        13
# 2  2020-03-18  New England Whalers        Station7  Inferno        12
# 3  2020-03-18              Rugratz  Bad News Bears  Inferno         7
# 4  2020-03-18              Rugratz  Bad News Bears  Vertigo         8
#
#    result_2  map_winner  starting_ct  ct_1  t_2  t_1  ct_2  event_id  \
# 0        16           2            2     0    1    0    15      5151
# 1        16           2            2     8    6    5    10      5151
# 2        16           2            1     9    6    3    10      5243
# 3        16           2            2     0    8    7     8      5151
# 4        16           2            2     4    5    4    11      5151
#
#    match_id  rank_1  rank_2  map_wins_1  map_wins_2  match_winner
# 0   2340454      62      63           0           2             2
# 1   2340454      62      63           0           2             2
# 2   2340461     140     118          12          16             2
# 3   2340453      61      38           0           2             2
# 4   2340453      61      38           0           2             2

# %%
matches.shape
# Out:
# (45773, 19)

# %% [markdown]
# Cleaning Match Data

# %%
matches.dtypes
# Out:
# date            object
# team_1          object
# team_2          object
# _map            object
# result_1         int64
# result_2         int64
# map_winner       int64
# starting_ct      int64
# ct_1             int64
# t_2              int64
# t_1              int64
# ct_2             int64
# event_id         int64
# match_id         int64
# rank_1           int64
# rank_2           int64
# map_wins_1       int64
# map_wins_2       int64
# match_winner     int64
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches.dtypes
# Out:
# date            datetime64[ns]
# team_1                  object
# team_2                  object
# _map                    object
# result_1                 int64
# result_2                 int64
# map_winner               int64
# starting_ct              int64
# ct_1                     int64
# t_2                      int64
# t_1                      int64
# ct_2                     int64
# event_id                 int64
# match_id                 int64
# rank_1                   int64
# rank_2                   int64
# map_wins_1               int64
# map_wins_2               int64
# match_winner             int64
# dtype: object

# %% [markdown]
# Creating Match Predictors

# %%
matches["map_code"] = matches['_map'].astype("category").cat.codes
matches["opp_code"] = matches['team_2'].astype("category").cat.codes
matches["ct_code"] = matches['starting_ct'].astype("category").cat.codes
matches["target"] = matches['map_winner'].astype("category").cat.codes
matches
# Out:
#             date               team_1          team_2         _map  result_1  \
# 0     2020-03-18              Recon 5         TeamOne        Dust2         0
# 1     2020-03-18              Recon 5         TeamOne      Inferno        13
# 2     2020-03-18  New England Whalers        Station7      Inferno        12
# 3     2020-03-18              Rugratz  Bad News Bears      Inferno         7
# 4     2020-03-18              Rugratz  Bad News Bears      Vertigo         8
# ...          ...                  ...             ...          ...       ...
# 45768 2015-11-05                   G2      E-frag.net      Inferno        13
# 45769 2015-11-05                   G2      E-frag.net        Dust2        16
# 45770 2015-11-04                  CLG          Liquid      Inferno        16
# 45771 2015-11-03                  NiP        Dignitas        Train        16
# 45772 2015-11-03                  NiP            Envy  Cobblestone        16
#
#        result_2  map_winner  starting_ct  ct_1  t_2  ...  match_id  rank_1  \
# 0            16           2            2     0    1  ...   2340454      62
# 1            16           2            2     8    6  ...   2340454      62
# 2            16           2            1     9    6  ...   2340461     140
# 3            16           2            2     0    8  ...   2340453      61
# 4            16           2            2     4    5  ...   2340453      61
# ...         ...         ...          ...   ...  ...  ...       ...     ...
# 45768        16           2            1     8    7  ...   2299059       7
# 45769        13           1            1    10    5  ...   2299059       7
# 45770        12           1            1     7    8  ...   2299011      10
# 45771         4           1            2     4    1  ...   2299001       6
# 45772         9           1            2     4    6  ...   2299003       6
#
#        rank_2  map_wins_1  map_wins_2  match_winner  map_code  opp_code  \
# 0          63           0           2             2         3      1053
# 1          63           0           2             2         4      1053
# 2         118          12          16             2         4      1014
# 3          38           0           2             2         4       136
# 4          38           0           2             2         9       136
# ...       ...         ...         ...           ...       ...       ...
# 45768      16           1           2             2         4       295
# 45769      16           1           2             2         3       295
# 45770      14          16          12             1         4       620
# 45771      12          16           4             1         8       274
# 45772       1          16           9             1         1       338
#
#        ct_code  target
# 0            1       1
# 1            1       1
# 2            0       1
# 3            1       1
# 4            1       1
# ...        ...     ...
# 45768        0       1
# 45769        0       0
# 45770        0       0
# 45771        1       0
# 45772        1       0
#
# [45773 rows x 23 columns]

# %% [markdown]
# Creating Initial Model

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

train = matches[matches["date"] < '2018-01-01']
test = matches[matches["date"] >= '2018-01-01']

predictors = ["map_code", "opp_code", "ct_code"]
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test["target"], preds)
# Out:
# 0.515420981539847

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted     0     1
# actual
# 0          8535  5747
# 1          7168  5202

# %%
from sklearn.metrics import precision_score
precision_score(test["target"], preds)
# Out:
# 0.4751118823636862

# %% [markdown]
# Improving Model Precision

# %%
grouped_matches = matches.groupby("team_1")
group = grouped_matches.get_group("fnatic")
group
#
# Out:
#             date  team_1         team_2      _map  result_1  result_2  \
# 9     2020-03-17  fnatic            BIG    Mirage        12        16
# 21    2020-03-17  fnatic            BIG  Overpass        16         7
# 26    2020-03-17  fnatic            BIG   Inferno         7        16
# 405   2020-03-07  fnatic       Dignitas  Overpass        16         3
# 406   2020-03-07  fnatic       Dignitas   Inferno        19        15
# ...          ...     ...            ...       ...       ...       ...
# 45621 2015-11-18  fnatic            TSM     Dust2        16        11
# 45629 2015-11-18  fnatic            TSM   Inferno        16        14
# 45671 2015-11-17  fnatic           Envy   Inferno        16        10
# 45675 2015-11-16  fnatic  Natus Vincere     Dust2        16         3
# 45676 2015-11-16  fnatic  Natus Vincere   Inferno        16         3
#
#        map_winner  starting_ct  ct_1  t_2  ...  match_id  rank_1  rank_2  \
# 9               2            1     9    6  ...   2340397       5      18
# 21              1            2     4    4  ...   2340397       5      18
# 26              2            1     5   10  ...   2340397       5      18
# 405             1            1    15    0  ...   2340160       4      44
# 406             1            2     4   11  ...   2340160       4      44
# ...           ...          ...   ...  ...  ...       ...     ...     ...
# 45621           1            2     5    7  ...   2299361       4       3
# 45629           1            2     8    7  ...   2299361       4       3
# 45671           1            1     7    8  ...   2299339       4       1
# 45675           1            2     3    1  ...   2299286       4       5
# 45676           1            1    12    3  ...   2299286       4       5
#
#        map_wins_1  map_wins_2  match_winner  map_code  opp_code  ct_code  \
# 9               1           2             2         5       121        0
# 21              1           2             2         7       121        1
# 26              1           2             2         4       121        0
# 405             2           1             1         7       274        0
# 406             2           1             1         4       274        1
# ...           ...         ...           ...       ...       ...      ...
# 45621           2           0             1         3      1043        1
# 45629           2           0             1         4      1043        1
# 45671          16          10             1         4       338        0
# 45675           2           0             1         3       711        1
# 45676           2           0             1         4       711        0
#
#        target
# 9           1
# 21          0
# 26          1
# 405         0
# 406         0
# ...       ...
# 45621       0
# 45629       0
# 45671       0
# 45675       0
# 45676       0
#
# [454 rows x 23 columns]
# Warning: Total number of columns (23) exceeds max_columns (20) limiting to first (20) columns.

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["ct_1", "ct_2", "t_1", "t_2"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#             date  team_1    team_2         _map  result_1  result_2  \
# 45629 2015-11-18  fnatic       TSM      Inferno        16        14
# 45621 2015-11-18  fnatic       TSM        Dust2        16        11
# 45577 2015-11-24  fnatic  Dignitas        Cache        16        10
# 45579 2015-11-24  fnatic  Dignitas        Train        16         8
# 45578 2015-11-24  fnatic  Dignitas  Cobblestone        17        19
# ...          ...     ...       ...          ...       ...       ...
# 406   2020-03-07  fnatic  Dignitas      Inferno        19        15
# 405   2020-03-07  fnatic  Dignitas     Overpass        16         3
# 26    2020-03-17  fnatic       BIG      Inferno         7        16
# 21    2020-03-17  fnatic       BIG     Overpass        16         7
# 9     2020-03-17  fnatic       BIG       Mirage        12        16
#
#        map_winner  starting_ct  ct_1  t_2  ...  map_wins_2  match_winner  \
# 45629           1            2     8    7  ...           0             1
# 45621           1            2     5    7  ...           0             1
# 45577           1            2    10    1  ...           1             1
# 45579           1            2     5    4  ...           1             1
# 45578           2            2    11    4  ...           1             1
# ...           ...          ...   ...  ...  ...         ...           ...
# 406             1            2     4   11  ...           1             1
# 405             1            1    15    0  ...           1             1
# 26              2            1     5   10  ...           2             2
# 21              1            2     4    4  ...           2             2
# 9               2            1     9    6  ...           2             2
#
#        map_code  opp_code  ct_code  target  ct_1_rolling  ct_2_rolling  \
# 45629         4      1043        1       0      7.333333      1.333333
# 45621         3      1043        1       0      6.000000      3.666667
# 45577         0       274        1       0      6.666667      4.333333
# 45579         8       274        1       0      7.666667      6.666667
# 45578         1       274        1       1      6.666667      5.666667
# ...         ...       ...      ...     ...           ...           ...
# 406           4       274        1       0      7.333333      4.333333
# 405           7       274        0       0      5.666667      5.333333
# 26            4       121        0       1      8.666667      4.666667
# 21            7       121        1       0      8.000000      4.333333
# 9             5       121        0       1      8.000000      4.000000
#
#        t_1_rolling  t_2_rolling
# 45629     8.666667     4.000000
# 45621    10.000000     5.333333
# 45577     9.333333     7.333333
# 45579     8.333333     5.000000
# 45578     9.333333     4.000000
# ...            ...          ...
# 406       8.333333     5.000000
# 405       9.666667     6.666667
# 26        6.666667     6.333333
# 21        4.666667     7.000000
# 9         5.000000     4.666667
#
# [451 rows x 27 columns]

# %%
matches_rolling = matches.groupby("team_1").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling = matches_rolling.droplevel('team_1')
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
# <ipython-input-68-a60559e37289>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team_1").apply(lambda x: rolling_averages(x, cols, new_cols))
#             date       team_1          team_2      _map  result_1  result_2  \
# 0     2019-11-08  100 Thieves            ENCE   Inferno        16         9
# 1     2019-11-10  100 Thieves        Astralis     Train         3        16
# 2     2019-11-10  100 Thieves        Astralis      Nuke         5        16
# 3     2019-11-10  100 Thieves        Astralis   Vertigo        14        16
# 4     2019-11-17  100 Thieves         eUnited    Mirage        16         7
# ...          ...          ...             ...       ...       ...       ...
# 42382 2017-02-06      zARLANS          E-Corp      Nuke        10        16
# 42383 2017-02-06      zARLANS          E-Corp  Overpass        16         8
# 42384 2017-02-22      zARLANS    spray'n'pray   Inferno        13        16
# 42385 2017-05-09      zARLANS    spray'n'pray    Mirage        19        22
# 42386 2017-05-24      zARLANS  Spirit Academy   Inferno        15        19
#
#        map_winner  starting_ct  ct_1  t_2  ...  map_wins_2  match_winner  \
# 0               1            2     7    3  ...           0             1
# 1               2            2     0    4  ...           3             2
# 2               2            1     4   11  ...           3             2
# 3               2            2     7    8  ...           3             2
# 4               1            2     6    2  ...           0             1
# ...           ...          ...   ...  ...  ...         ...           ...
# 42382           2            1     7    8  ...           1             1
# 42383           1            1    11    4  ...           1             1
# 42384           2            1     5   10  ...          16             2
# 42385           2            2    10    5  ...          22             2
# 42386           2            2     8    7  ...          19             2
#
#        map_code  opp_code  ct_code  target  ct_1_rolling  ct_2_rolling  \
# 0             4       302        1       0      6.333333      2.666667
# 1             8       107        1       1      7.333333      4.000000
# 2             6       107        0       1      6.000000      7.000000
# 3             9       107        1       1      3.666667      7.666667
# 4             5      1262        1       0      3.666667      8.333333
# ...         ...       ...      ...     ...           ...           ...
# 42382         6       294        0       1      5.333333      8.000000
# 42383         7       294        0       0      5.666667      8.333333
# 42384         4      1383        0       1      9.000000      6.666667
# 42385         5      1383        1       1      7.666667      6.000000
# 42386         4      1008        1       1      8.666667      6.666667
#
#        t_1_rolling  t_2_rolling
# 0         9.666667     5.000000
# 1         8.666667     2.333333
# 2         5.666667     3.666667
# 3         4.333333     6.000000
# 4         3.666667     7.666667
# ...            ...          ...
# 42382     5.333333     6.666667
# 42383     5.333333     6.333333
# 42384     5.000000     5.333333
# 42385     5.333333     7.333333
# 42386     6.000000     6.333333
#
# [42387 rows x 27 columns]

# %% [markdown]
# Retraining Model

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2018-01-01']
    test = data[data["date"] >= '2018-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)
precision
# Out:
# 0.4894106256807455

# %%
combined = combined.merge(matches_rolling[["date", "team_1", "team_2", "map_winner"]], left_index=True, right_index=True)
combined
# Out:
#        actual  predicted       date          team_1    team_2  map_winner
# 0           0          0 2019-11-08     100 Thieves      ENCE           1
# 1           1          0 2019-11-10     100 Thieves  Astralis           2
# 2           1          0 2019-11-10     100 Thieves  Astralis           2
# 3           1          1 2019-11-10     100 Thieves  Astralis           2
# 4           0          1 2019-11-17     100 Thieves   eUnited           1
# ...       ...        ...        ...             ...       ...         ...
# 42364       1          0 2019-02-21  x6tence Galaxy    Sprout           2
# 42365       1          1 2019-02-21  x6tence Galaxy    Sprout           2
# 42366       1          0 2019-03-07  x6tence Galaxy   Epsilon           2
# 42367       0          1 2019-03-07  x6tence Galaxy   Epsilon           1
# 42368       1          1 2019-03-07  x6tence Galaxy   Epsilon           2
#
# [25150 rows x 6 columns]

# %% [markdown]
# **Next Steps:**
# Add more insightful data, such as team rank, kills, deaths, or assists
